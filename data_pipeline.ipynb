# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiruba-Sherlin/Data-pipeline/blob/main/data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os

# %%
#EXTRACT
# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target, name='target')

# Optional: map numeric target to class names for better readability
target_names = iris.target_names
y_named = y.map(lambda idx: target_names[idx])

# Combine features and target into one DataFrame
df = pd.concat([X, y_named.rename("species")], axis=1)

# Preview the original data
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
#TRANSFORM
# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_named)

# Create the final processed DataFrame
processed_df = pd.DataFrame(X_scaled, columns=iris.feature_names)
processed_df['species'] = y_encoded

# Preview the transformed data
processed_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#LOAD
# Define output directory
output_dir = 'data/processed'
os.makedirs(output_dir, exist_ok=True)

# Save to CSV
processed_df.to_csv(f'{output_dir}/iris_cleaned.csv', index=False)

print("✅ Cleaned Iris data saved to 'data/processed/iris_cleaned.csv'")
# Out:
# ✅ Cleaned Iris data saved to 'data/processed/iris_cleaned.csv'
